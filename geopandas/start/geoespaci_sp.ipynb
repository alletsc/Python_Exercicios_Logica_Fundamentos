# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
#fonte dos dados: https://geoftp.ibge.gov.br/

data = gpd.read_file(
    "S:\gits_stella\Python\python_start\geopandas\dados\SP_Municipios_2020.shp")
type(data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
data.head()
# Out:
#     CD_MUN            NM_MUN SIGLA_UF  AREA_KM2  \
# 0  3500105        Adamantina       SP   411.987
# 1  3500204            Adolfo       SP   211.055
# 2  3500303             Aguaí       SP   474.554
# 3  3500402    Águas da Prata       SP   142.673
# 4  3500501  Águas de Lindóia       SP    60.126
#
#                                             geometry
# 0  POLYGON ((-51.05425 -21.40465, -51.05300 -21.4...
# 1  POLYGON ((-49.65795 -21.20333, -49.65645 -21.2...
# 2  POLYGON ((-46.97640 -21.96818, -46.97599 -21.9...
# 3  POLYGON ((-46.73501 -21.81891, -46.73431 -21.8...
# 4  POLYGON ((-46.60614 -22.44173, -46.60347 -22.4...

# %%
#plot municipios SP
data.plot()
# Out:
# <AxesSubplot:>

# %%
# filtrando região da capital
capital = data[data['NM_MUN'] == 'São Paulo']
capital.plot(figsize=(10,8), color='white', edgecolor='black')
# Out:
# <AxesSubplot:>

# %%
#salvar a capital como GeoDF
capital.to_file("capital.shp")

# %%
capital = gpd.read_file('S:\gits_stella\Python\python_start\geopandas\dados\capital_sp\capital.shp')
capital
# Out:
#     CD_MUN     NM_MUN SIGLA_UF  AREA_KM2  \
# 0  3550308  São Paulo       SP   1521.11
#
#                                             geometry
# 0  POLYGON ((-46.54624 -23.35791, -46.54585 -23.3...
