# %%
# %matplotlib inline
import geopandas as gpd

# %%
rj = gpd.read_file('S:\gits_stella\Python\python_start\geopandas\RJ-MUNIC.shp')
geo_dados = gpd.read_file(
    'S:\gits_stella\Python\python_start\geopandas\DATASET.shp')

# %%
base = rj.plot(color='black', edgecolor='black', figsize=(15, 8))
base
# Out:
# <AxesSubplot:>

# %%
#plot em camadas
base = rj.plot(color='black', edgecolor='black', figsize=(15, 8))
geo_dados.plot(ax=base, figsize=(15, 8), alpha=0.02)
# Out:
# <AxesSubplot:>

# %%
#selecionando os municipios dentro da area base
rj.iloc[0].geometry
geo_dados.iloc[0]
# Out:
# Area                                                 138
# Bairro                          Recreio dos Bandeirantes
# Cidade                                    Rio de Janeiro
# Endereco                             Rua Vicente Scofano
# Estado                                                RJ
# Latitude                                      -23.016455
# Longitude                                     -43.462946
# Quartos                                                3
# Suites                                                 1
# Vagas                                                  3
# Tipo                                         Apartamento
# Transacao                                          Venda
# Valor                                            1095000
# geometry     POINT (657.5137068691058 7453.832425203198)
# Name: 0, dtype: object

# %%
geo_dados.iloc[0].geometry

# %%
geo_dados.iloc[0].geometry.within(rj.iloc[0].geometry)
# Out:
# False

# %%
geo_dados['geometry'].within(rj.iloc[0].geometry)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool
